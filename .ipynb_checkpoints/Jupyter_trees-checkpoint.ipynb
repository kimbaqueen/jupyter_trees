# %%
conda install pandas
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.13.0
#   latest version: 4.14.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/kimbaqueen/opt/anaconda3/envs/Jupyter_trees
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bottleneck-1.3.5           |   py39h67323c0_0         121 KB
#     numexpr-2.8.3              |   py39h2e5f0a9_0         120 KB
#     numpy-1.23.1               |   py39h2e5f0a9_0          11 KB
#     numpy-base-1.23.1          |   py39h3b1a694_0         5.3 MB
#     pandas-1.4.3               |   py39he9d5cce_0         9.4 MB
#     pytz-2022.1                |   py39hecd8cb5_0         195 KB
#     ------------------------------------------------------------
#                                            Total:        15.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/osx-64::blas-1.0-mkl
#   bottleneck         pkgs/main/osx-64::bottleneck-1.3.5-py39h67323c0_0
#   intel-openmp       pkgs/main/osx-64::intel-openmp-2021.4.0-hecd8cb5_3538
#   mkl                pkgs/main/osx-64::mkl-2021.4.0-hecd8cb5_637
#   mkl-service        pkgs/main/osx-64::mkl-service-2.4.0-py39h9ed2024_0
#   mkl_fft            pkgs/main/osx-64::mkl_fft-1.3.1-py39h4ab4a9b_0
#   mkl_random         pkgs/main/osx-64::mkl_random-1.2.2-py39hb2f4e1b_0
#   numexpr            pkgs/main/osx-64::numexpr-2.8.3-py39h2e5f0a9_0
#   numpy              pkgs/main/osx-64::numpy-1.23.1-py39h2e5f0a9_0
#   numpy-base         pkgs/main/osx-64::numpy-base-1.23.1-py39h3b1a694_0
#   pandas             pkgs/main/osx-64::pandas-1.4.3-py39he9d5cce_0
#   pytz               pkgs/main/osx-64::pytz-2022.1-py39hecd8cb5_0
#
#
#
# Downloading and Extracting Packages
# numpy-1.23.1         | 11 KB     | ##################################### | 100%
# pandas-1.4.3         | 9.4 MB    | ##################################### | 100%
# pytz-2022.1          | 195 KB    | ##################################### | 100%
# numpy-base-1.23.1    | 5.3 MB    | ##################################### | 100%
# numexpr-2.8.3        | 120 KB    | ##################################### | 100%
# bottleneck-1.3.5     | 121 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda update -n base -c defaults conda
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/kimbaqueen/opt/anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.14.0               |   py39hecd8cb5_0         925 KB
#     conda-repo-cli-1.0.5       |   py39hecd8cb5_0         106 KB
#     pathlib-1.0.1              |     pyhd3eb1b0_1          17 KB
#     pyjwt-2.4.0                |   py39hecd8cb5_0          35 KB
#     ------------------------------------------------------------
#                                            Total:         1.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   pathlib            pkgs/main/noarch::pathlib-1.0.1-pyhd3eb1b0_1
#
# The following packages will be UPDATED:
#
#   conda                               4.13.0-py39hecd8cb5_0 --> 4.14.0-py39hecd8cb5_0
#   conda-repo-cli     pkgs/main/noarch::conda-repo-cli-1.0.~ --> pkgs/main/osx-64::conda-repo-cli-1.0.5-py39hecd8cb5_0
#   pyjwt                                2.1.0-py39hecd8cb5_0 --> 2.4.0-py39hecd8cb5_0
#
#
#
# Downloading and Extracting Packages
# conda-4.14.0         | 925 KB    | ##################################### | 100%
# pyjwt-2.4.0          | 35 KB     | ##################################### | 100%
# pathlib-1.0.1        | 17 KB     | ##################################### | 100%
# conda-repo-cli-1.0.5 | 106 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data = pd.read_csv('Street_Tree_List.csv')

# %%
data.head()
# Out:
#    TreeID    qLegalStatus                                           qSpecies  \
# 0   48142  Permitted Site                                         Tree(s) ::
# 1   19725  DPW Maintained                              Pinus Spp :: Pine Spp
# 2  121399  DPW Maintained            Corymbia ficifolia :: Red Flowering Gum
# 3   46536  Permitted Site                                         Tree(s) ::
# 4  251210  DPW Maintained  Eucalyptus polyanthemos :: Silver Dollar Eucal...
#
#           qAddress  SiteOrder                     qSiteInfo PlantType  \
# 0              NaN      252.0  Sidewalk: Curb side : Cutout      Tree
# 1   100 STAIRWAY14        3.0  Sidewalk: Curb side : Cutout      Tree
# 2   349X Cargo Way        1.0  Sidewalk: Curb side : Cutout      Tree
# 3     73 Summer St        2.0  Sidewalk: Curb side : Cutout      Tree
# 4  1170 Ingalls St        2.0  Sidewalk: Curb side : Cutout      Tree
#
#   qCaretaker qCareAssistant               PlantDate  ...  XCoord YCoord  \
# 0    Private            NaN  07/17/2002 12:00:00 AM  ...     NaN    NaN
# 1        DPW            NaN                     NaN  ...     NaN    NaN
# 2        DPW            NaN                     NaN  ...     NaN    NaN
# 3    Private            NaN  04/01/2002 12:00:00 AM  ...     NaN    NaN
# 4        DPW            NaN  11/02/1992 12:00:00 AM  ...     NaN    NaN
#
#   Latitude  Longitude  Location  Fire Prevention Districts  Police Districts  \
# 0      NaN        NaN       NaN                        NaN               NaN
# 1      NaN        NaN       NaN                        NaN               NaN
# 2      NaN        NaN       NaN                        NaN               NaN
# 3      NaN        NaN       NaN                        NaN               NaN
# 4      NaN        NaN       NaN                        NaN               NaN
#
#   Supervisor Districts  Zip Codes  Neighborhoods (old)
# 0                  NaN        NaN                  NaN
# 1                  NaN        NaN                  NaN
# 2                  NaN        NaN                  NaN
# 3                  NaN        NaN                  NaN
# 4                  NaN        NaN                  NaN
#
# [5 rows x 23 columns]

# %%
conda install numpy
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('Street_Tree_List.csv')

# %%
data.nunique()
# Out:
# TreeID                       196458
# qLegalStatus                     12
# qSpecies                        577
# qAddress                      87284
# SiteOrder                       312
# qSiteInfo                        33
# PlantType                         3
# qCaretaker                       24
# qCareAssistant                   18
# PlantDate                      9404
# DBH                             109
# PlotSize                        603
# PermitNotes                   35584
# XCoord                       162138
# YCoord                       162596
# Latitude                     164202
# Longitude                    164205
# Location                     164205
# Fire Prevention Districts        15
# Police Districts                 10
# Supervisor Districts             11
# Zip Codes                        29
# Neighborhoods (old)              41
# dtype: int64

# %% [markdown]
# # Total Zip unique Zip codes values: 29

# %%
print(data['SiteOrder'].sum())
# Out:
# 888764.0

# %% [markdown]
# # Total number of trees: 888,764
